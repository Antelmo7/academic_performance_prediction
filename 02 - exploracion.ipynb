# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# load dataset
academic_performance = pd.read_csv('enhanced_student_habits_performance_dataset.csv')

# show first rows
academic_performance.head(9)
# Out:
#    student_id  age  gender             major  study_hours_per_day  \
# 0      100000   26    Male  Computer Science             7.645367
# 1      100001   28    Male              Arts             5.700000
# 2      100002   17    Male              Arts             2.400000
# 3      100003   27   Other        Psychology             3.400000
# 4      100004   25  Female          Business             4.700000
# 5      100005   17  Female       Engineering             4.200000
# 6      100006   19    Male        Psychology             4.100000
# 7      100007   17    Male        Psychology             4.100000
# 8      100008   28  Female        Psychology             0.600000
#
#    social_media_hours  netflix_hours part_time_job  attendance_percentage  \
# 0                 3.0            0.1           Yes                   70.3
# 1                 0.5            0.4            No                   88.4
# 2                 4.2            0.7            No                   82.1
# ...

# %%
# estadisticas descriptivas generales
academic_performance.describe() # resumen rapido
# Out:
#           student_id           age  study_hours_per_day  social_media_hours  \
# count   80000.000000  80000.000000         80000.000000        80000.000000
# mean   139999.500000     22.004288             4.174388            2.501366
# std     23094.155105      3.745570             2.004135            1.445441
# min    100000.000000     16.000000             0.000000            0.000000
# 25%    119999.750000     19.000000             2.800000            1.200000
# 50%    139999.500000     22.000000             4.125624            2.500000
# 75%    159999.250000     25.000000             5.500000            3.800000
# max    179999.000000     28.000000            12.000000            5.000000
#
#        netflix_hours  attendance_percentage   sleep_hours  exercise_frequency  \
# count   80000.000000           80000.000000  80000.000000        80000.000000
# mean        1.997754              69.967884      7.017418            3.516587
# ...

# %%
# Scatterplot de horas de estudio vs califacion examen (local)
sns.scatterplot(x='study_hours_per_day', y='exam_score', data=academic_performance)
plt.title('Relación entre horas de estudio diarias y puntaje de examen')
plt.show()

# %%
# mapa de calor de correlación entre variables clave
plt.figure(figsize=[10,6])
sns.heatmap(academic_performance[['study_hours_per_day', 'social_media_hours', 'netflix_hours', 'sleep_hours',
                                  'exercise_frequency', 'stress_level', 'screen_time',
                                  'motivation_level', 'exam_anxiety_score', 'time_management_score', 'exam_score']].corr(), annot=True, cmap='coolwarm')
plt.title('Mapa de calor - Correlación entre variables')
plt.show()
